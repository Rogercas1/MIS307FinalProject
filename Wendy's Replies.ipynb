# %% [markdown]
# Importing everything good and setting up authorization.

# %%
import tweepy
import pandas as pd
from keys import *
import matplotlib.pylab as plt
import matplotlib.pyplot as plot 
from textblob import TextBlob

api = tweepy.API(tweepy.OAuth2BearerHandler(bearer_token))
name = 'Wendys'
spacing_values = [-1, -.8, -.6, -.4, -.2, 0, .2, .4, .6, .8, 1]

# %% [markdown]
# ------
#
# First Wendy's Tweet (1518681018466721792)

# %%
tweet_id = '1518681018466721792'

replies=[]
for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(250):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)

# %%
id_list = []
text_list = []
for item in replies:
    text_list.append(item.text)
    id_list.append(item.id)

# %%
d = {'id':id_list, 'text':text_list}
df = pd.DataFrame(d)

df['Polarity'] = df['text'].apply(lambda x: float(TextBlob(x).sentiment.polarity))
df.loc[:,'Classification'] = 'neutral'
df.loc[df['Polarity'] > 0.03, 'Classification'] = 'positive'
df.loc[df['Polarity'] < -0.03, 'Classification'] = 'negative'

# %%
fig, ax = plt.subplots()
fig.suptitle(f"Polarity of replies over Wendy's Tweet: '1518681018466721792' out of {len(replies)} replies", multialignment='center', wrap=True)
ax.hist(df['Polarity'], range=[-1, 1])
ax.grid(which='major', color='grey', linestyle='--')
plot.xticks(spacing_values)
ax.set_xlabel('Polarity')
ax.set_ylabel('Amount')
ax;

# %% [markdown]
# ------
#
# Second Wendy's Tweet (1517169828590764036)

# %%
tweet_id = '1517169828590764036'

replies=[]
for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(250):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)

# %%
id_list = []
text_list = []
for item in replies:
    text_list.append(item.text)
    id_list.append(item.id)

# %%
d = {'id':id_list, 'text':text_list}
df = pd.DataFrame(d)

df['Polarity'] = df['text'].apply(lambda x: float(TextBlob(x).sentiment.polarity))
df.loc[:,'Classification'] = 'neutral'
df.loc[df['Polarity'] > 0.03, 'Classification'] = 'positive'
df.loc[df['Polarity'] < -0.03, 'Classification'] = 'negative'

# %%
fig, ax = plt.subplots()
fig.suptitle(f"Polarity of replies over Wendy's Tweet: '1517169828590764036' out of {len(replies)} replies", multialignment='center', wrap=True)
ax.hist(df['Polarity'])
ax.grid(which='major', color='grey', linestyle='--')
plot.xticks(spacing_values)
ax.set_xlabel('Polarity')
ax.set_ylabel('Amount')
ax;

# %% [markdown]
# ------
#
# Third Wendy's Tweet (1514667895497887748)

# %%
tweet_id = '1514667895497887748'

replies=[]
for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(250):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)
x = 1
for item in replies:
    print(x)
    x += 1
# Out:
# 1

# %%
id_list = []
text_list = []
for item in replies:
    text_list.append(item.text)
    id_list.append(item.id)

# %%
d = {'id':id_list, 'text':text_list}
df = pd.DataFrame(d)

df['Polarity'] = df['text'].apply(lambda x: float(TextBlob(x).sentiment.polarity))
df.loc[:,'Classification'] = 'neutral'
df.loc[df['Polarity'] > 0.03, 'Classification'] = 'positive'
df.loc[df['Polarity'] < -0.03, 'Classification'] = 'negative'

# %%
fig, ax = plt.subplots()
fig.suptitle(f"Polarity of replies over Wendy's Tweet: '1514667895497887748' out of {len(replies)} replies", multialignment='center', wrap=True)
ax.hist(df['Polarity'])
ax.grid(which='major', color='grey', linestyle='--')
plot.xticks(spacing_values)
ax.set_xlabel('Polarity')
ax.set_ylabel('Amount')
ax;

# %% [markdown]
# ------
#
# Fourth Wendy's Tweet (1511377350830788610)

# %%
tweet_id = '1511377350830788610'

replies=[]
for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(250):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)

# %%
id_list = []
text_list = []
for item in replies:
    text_list.append(item.text)
    id_list.append(item.id)

# %%
d = {'id':id_list, 'text':text_list}
df = pd.DataFrame(d)

df['Polarity'] = df['text'].apply(lambda x: float(TextBlob(x).sentiment.polarity))
df.loc[:,'Classification'] = 'neutral'
df.loc[df['Polarity'] > 0.03, 'Classification'] = 'positive'
df.loc[df['Polarity'] < -0.03, 'Classification'] = 'negative'

# %%
fig, ax = plt.subplots()
fig.suptitle(f"Polarity of replies over Wendy's Tweet: '1511377350830788610' out of {len(replies)} replies", multialignment='center', wrap=True)
ax.hist(df['Polarity'])
ax.grid(which='major', color='grey', linestyle='--')
plot.xticks(spacing_values)
ax.set_xlabel('Polarity')
ax.set_ylabel('Amount')
ax;

# %% [markdown]
# ------
#
# Fifth Wendy's Tweet (1510643384419037186)

# %%
tweet_id = '1510643384419037186'

replies=[]
for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(250):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)

# %%
id_list = []
text_list = []
for item in replies:
    text_list.append(item.text)
    id_list.append(item.id)

# %%
d = {'id':id_list, 'text':text_list}
df = pd.DataFrame(d)

df['Polarity'] = df['text'].apply(lambda x: float(TextBlob(x).sentiment.polarity))
df.loc[:,'Classification'] = 'neutral'
df.loc[df['Polarity'] > 0.03, 'Classification'] = 'positive'
df.loc[df['Polarity'] < -0.03, 'Classification'] = 'negative'

# %%
fig, ax = plt.subplots()
fig.suptitle(f"Polarity of replies over Wendy's Tweet: '1510643384419037186' out of {len(replies)} replies", multialignment='center', wrap=True)
ax.hist(df['Polarity'])
ax.grid(which='major', color='grey', linestyle='--')
plot.xticks(spacing_values)
ax.set_xlabel('Polarity')
ax.set_ylabel('Amount')
ax;
